# %% [markdown]
# <a href="https://colab.research.google.com/github/naveenkumar1805/sample_longist_data_analysis/blob/main/Copy_of_sample_longlist_data.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import pandas as pd
import numpy as np

# %%
file_path = "/content/drive/MyDrive/Sample_Longlist_Data.csv"
df=pd.read_csv(file_path, encoding='unicode_escape')

# %%
df.shape
# Out:
# (1839, 21)

# %%
df.head(5)
# Out:
#   Date Added category sellerlink sellerlink-url     sellerstorefront-url  \
# 0  15-Nov-20   Garden   Seller 1  Seller 1-link  Seller 1-storefrontlink
# 1  15-Nov-20   Garden   Seller 2  Seller 2-link  Seller 2-storefrontlink
# 2  15-Nov-20   Garden   Seller 3  Seller 3-link  Seller 3-storefrontlink
# 3  15-Nov-20   Garden   Seller 4  Seller 4-link  Seller 4-storefrontlink
# 4  15-Nov-20   Garden   Seller 5  Seller 5-link  Seller 5-storefrontlink
#
#              sellerproductcount  \
# 0  1-16 of over 100,000 results
# 1                           NaN
# 2    1-16 of over 2,000 results
# 3           1-16 of 123 results
# 4    1-16 of over 1,000 results
#
#                                       sellerratings  \
# 0  88% positive in the last 12 months (118 ratings)
# 1  90% positive in the last 12 months (566 ratings)
# 2   85% positive in the last 12 months (75 ratings)
# 3                                               NaN
# 4   81% positive in the last 12 months (52 ratings)
#
# ...

# %%
df.columns
# Out:
# Index(['Date Added', 'category', 'sellerlink', 'sellerlink-url',
#        'sellerstorefront-url', 'sellerproductcount', 'sellerratings',
#        'sellerdetails', 'seller business name', 'businessaddress',
#        'Count of seller brands',
#        'Max % of negative seller ratings - last 30 days',
#        'Max % of negative seller ratings - last 90 days',
#        'Max % of negative seller ratings - last 12 months',
#        'Hero Product 1 #ratings', 'Hero Product 2 #ratings',
#        'Sample brand name', 'Sample Brand URL', 'Unnamed: 18', 'Unnamed: 19',
#        'Unnamed: 20'],
#       dtype='object')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1839 entries, 0 to 1838
# Data columns (total 21 columns):
#  #   Column                                             Non-Null Count  Dtype
# ---  ------                                             --------------  -----
#  0   Date Added                                         1839 non-null   object
#  1   category                                           1839 non-null   object
#  2   sellerlink                                         1839 non-null   object
#  3   sellerlink-url                                     1839 non-null   object
#  4   sellerstorefront-url                               1839 non-null   object
#  5   sellerproductcount                                 1513 non-null   object
#  6   sellerratings                                      1411 non-null   object
#  7   sellerdetails                                      1812 non-null   object
# ...

# %%
df.describe()
# Out:
#        Count of seller brands  \
# count             1839.000000
# mean                 6.951060
# std                  6.232073
# min                  0.000000
# 25%                  1.000000
# 50%                  5.000000
# 75%                 15.000000
# max                 16.000000
#
#        Max % of negative seller ratings - last 30 days  \
# count                                      1839.000000
# mean                                          5.808592
# std                                          18.117027
# min                                           0.000000
# 25%                                           0.000000
# 50%                                           0.000000
# 75%                                           0.000000
# max                                         100.000000
#
#        Max % of negative seller ratings - last 90 days  \
# count                                      1839.000000
# mean                                          7.632409
# ...
